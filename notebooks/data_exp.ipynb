# %%
from datasets import load_dataset
# Login using e.g. `huggingface-cli login` to access this dataset
ds = load_dataset("Tobi-Bueck/customer-support-tickets")
# Out:
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import joblib 
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import LogisticRegression
from sklearn.svm import LinearSVC
from sklearn.metrics import accuracy_score, f1_score, classification_report
from sklearn.linear_model import SGDClassifier
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import make_pipeline

# %%
print(ds)
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['subject', 'body', 'answer', 'type', 'queue', 'priority', 'language', 'version', 'tag_1', 'tag_2', 'tag_3', 'tag_4', 'tag_5', 'tag_6', 'tag_7', 'tag_8'],
#         num_rows: 61765
#     })
# })

# %%
df = ds['train'].to_pandas()
df.info
# Out:
# <bound method DataFrame.info of                                                  subject  \
# 0                        Wesentlicher Sicherheitsvorfall
# 1                                     Account Disruption
# 2      Query About Smart Home System Integration Feat...
# 3                      Inquiry Regarding Invoice Details
# 4      Question About Marketing Agency Software Compa...
# ...                                                  ...
# 61760     Assistance Needed for IFTTT Docker Integration
# 61761        Bitten um Unterstützung bei der Integration
# 61762                                               None
# 61763            Hilfe bei digitalen Strategie-Problemen
# 61764  Optimierung Ihrer Datenanalyse-Plattform erlei...
#
#                                                     body  \
# 0      Sehr geehrtes Support-Team,\n\nich möchte eine...
# 1      Dear Customer Support Team,\n\nI am writing to...
# 2      Dear Customer Support Team,\n\nI hope this mes...
# 3      Dear Customer Support Team,\n\nI hope this mes...
# 4      Dear Support Team,\n\nI hope this message reac...
# ...                                                  ...
# 61760  I am facing integration problems with IFTTT Do...
# 61761  Sehr geehrte Kundenservice, ich möchte die Int...
# 61762  Hello Customer Support, I am inquiring about t...
# 61763  Die Qualität unserer digitalen Strategie-Bearb...
# 61764  Sehr geehrte Customer Support-Team, ich schrei...
#
#                                                   answer      type  \
# 0      Vielen Dank für die Meldung des kritischen Sic...  Incident
# 1      Thank you for reaching out, <name>. We are awa...  Incident
# 2      Thank you for your inquiry. Our products suppo...   Request
# 3      We appreciate you reaching out with your billi...   Request
# 4      Thank you for your inquiry. Our product suppor...   Problem
# ...                                                  ...       ...
# 61760  I would be happy to assist with the IFTTT Dock...   Problem
# 61761  Sehr geehrte [Name], vielen Dank für Ihren Kon...    Change
# 61762  We will send you detailed information on plans...   Request
# 61763  Um den digitalen Strategie-Impuls zu überprüfe...  Incident
# 61764  Sehr geehrter <name>, wir antworten Ihnen auf ...    Change
#
#                        queue priority language  version        tag_1  \
# 0          Technical Support     high       de     51.0     Security
# 1          Technical Support     high       en     51.0      Account
# 2      Returns and Exchanges   medium       en     51.0      Product
# 3       Billing and Payments      low       en     51.0      Billing
# 4        Sales and Pre-Sales   medium       en     51.0      Product
# ...                      ...      ...      ...      ...          ...
# 61760      Technical Support      low       en      NaN  Integration
# 61761      Technical Support   medium       de      NaN  Integration
# 61762   Billing and Payments      low       en      NaN      Billing
# 61763        Product Support     high       de      NaN     Feedback
# 61764    Sales and Pre-Sales   medium       de      NaN      Product
#
#              tag_2          tag_3          tag_4          tag_5 tag_6 tag_7  \
# 0           Outage     Disruption    Data Breach           None  None  None
# 1       Disruption         Outage             IT   Tech Support  None  None
# 2          Feature   Tech Support           None           None  None  None
# 3          Payment        Account  Documentation       Feedback  None  None
# 4          Feature       Feedback   Tech Support           None  None  None
# ...            ...            ...            ...            ...   ...   ...
# 61760   Disruption    Performance             IT   Tech Support  None  None
# 61761      Feature  Documentation   Tech Support           None  None  None
# 61762      Payment        Feature       Feedback          Sales  Lead  None
# 61763  Performance             IT   Tech Support           None  None  None
# 61764      Feature    Performance       Guidance  Documentation  None  None
#
#       tag_8
# 0      None
# 1      None
# 2      None
# 3      None
# 4      None
# ...     ...
# 61760  None
# 61761  None
# 61762  None
# 61763  None
# 61764  None
#
# [61765 rows x 16 columns]>

# %%
df_en = df[df['language'] == 'en'].copy()

# %%
df_en['queue'].value_counts()
# Out:
# queue
# Technical Support                  8149
# Product Support                    5305
# Customer Service                   4269
# IT Support                         3333
# Billing and Payments               2897
# Returns and Exchanges              1402
# Service Outages and Maintenance    1106
# Sales and Pre-Sales                 843
# Human Resources                     553
# General Inquiry                     404
# Name: count, dtype: int64

# %%
top_label=df_en['queue'].value_counts().head(10).index.tolist()
# print(top_label)

df_en['label'] = np.where(df_en['queue'].isin(top_label), df_en['queue'], 'other')

# %%
df_en['label'].value_counts()
# Out:
# label
# Technical Support                  8149
# Product Support                    5305
# Customer Service                   4269
# IT Support                         3333
# Billing and Payments               2897
# Returns and Exchanges              1402
# Service Outages and Maintenance    1106
# Sales and Pre-Sales                 843
# Human Resources                     553
# General Inquiry                     404
# Name: count, dtype: int64

# %%
print(len(df_en))
# Out:
# 28261

# %%
train, temp = train_test_split(df_en, test_size=0.2, stratify=df_en['label'], random_state=42)
valid, test = train_test_split(temp, test_size=0.5, stratify=temp['label'], random_state=42)

print(f"Train rows: {len(train)}")
print(f"Valid rows: {len(valid)}")
print(f"Test rows:  {len(test)}")
# Out:
# Train rows: 22608
# Valid rows: 2826
# Test rows:  2827

# %%
test['text'] = test['subject'].fillna('')+ '\n' + test['body'].fillna('')
valid['text'] = valid['subject'].fillna('')+ '\n' + valid['body'].fillna('')
train['text'] = train['subject'].fillna('')+ '\n' + train['body'].fillna('')

x_train = train['text']
y_train = train['label']

x_val = valid['text']
y_val = valid['label']

x_test = test['text']
y_test = test['label']

# %%
print(x_train)
# Out:
# 44125    Inquiry on Integration Options for SaaS Projec...
# 7424     \nDear Customer Support, I have serious concer...
# 1175     Enhancement of Marketing Platforms\nCustomer S...
# 43876    Inquiry Regarding Digital Marketing Strategy C...
# 20481    Update User Interface\nRequest to update the u...
#                                ...
# 15610    Support Inquiry for System Outage\nEncountered...
# 19565    Problem with Analytics\nThe analytics dashboar...
# 44659    Marketing Firm Faces Reduced Brand Engagement\...
# 12973    Query on Gaming Product Digital Promotion Tact...
# 9374     Assistance Needed with SaaS Downtime\nOur proj...
# Name: text, Length: 22608, dtype: object

# %%
print("--- Random Samples ---")
print(train[['text', 'label']].sample(3))

short_count = (train['text'].str.len() < 20).sum()
print(f"\nNumber of very short/empty texts: {short_count}")
# Out:
# --- Random Samples ---
#                                                     text              label
# 17497  Guidance on Optimizing Django Investments with...         IT Support
# 8112   Security Concern Regarding Healthcare Data\nA ...  Technical Support
# 15369  Concerns Regarding Gamepad Integration Perform...  Technical Support
#
# Number of very short/empty texts: 3

# %%
x_train.head(100)
# Out:
# 44125    Inquiry on Integration Options for SaaS Projec...
# 7424     \nDear Customer Support, I have serious concer...
# 1175     Enhancement of Marketing Platforms\nCustomer S...
# 43876    Inquiry Regarding Digital Marketing Strategy C...
# 20481    Update User Interface\nRequest to update the u...
#                                ...
# 21542    Trouble with Zoho Integration\nExperienced dif...
# 7489     Request for Assistance with Data Delay Issues\...
# 20688    Request for Notion Integration Support\nCould ...
# 23187    Security of Healthcare Data\nIs there any poss...
# 58217    Enhance Digital Growth with Microsoft Azure an...
# Name: text, Length: 100, dtype: object

# %%
vectorizer = TfidfVectorizer()
X_train_tfidf = vectorizer.fit_transform(x_train)
vectorizer.get_feature_names_out()
print(X_train_tfidf.shape)
# Out:
# (22608, 5891)

# %%
# clf = LogisticRegression(class_weight='balanced',max_iter=1000, random_state=42)
# clf.fit(X_train_tfidf, y_train)
# x_lr = vectorizer.transform(x_val)
# y_pred_lr = clf.predict(x_lr)
# lr_acc = accuracy_score (y_val, y_pred_lr)
# lr_f1 = f1_score(y_val, y_pred_lr, average='macro')

# print(f"Validation Accuracy: {lr_acc:.4f}")
# print(f"Validation Macro F1: {lr_f1:.4f}")

# print("\nReport")
# print(classification_report(y_val, y_pred_lr))

# %%
svm = LinearSVC(class_weight='balanced', max_iter=100, random_state=42)
svm.fit(X_train_tfidf, y_train) 
x_svm = vectorizer.transform(x_val)
y_pred_svm = svm.predict(x_svm)

svm_acc = accuracy_score (y_val, y_pred_svm)
svm_f1 = f1_score(y_val, y_pred_svm, average='macro')
print(f"Validation Accuracy: {svm_acc:.4f}")
print(f"Validation Macro F1: {svm_f1:.4f}")

print("\nReport")
print(classification_report(y_val, y_pred_svm))
# Out:
# Validation Accuracy: 0.5223
# Validation Macro F1: 0.5052
#
# Report
#                                  precision    recall  f1-score   support
#
#            Billing and Payments       0.78      0.82      0.80       289
#                Customer Service       0.52      0.44      0.48       427
#                 General Inquiry       0.26      0.49      0.34        41
#                 Human Resources       0.39      0.70      0.50        56
#                      IT Support       0.45      0.48      0.46       333
#                 Product Support       0.52      0.44      0.47       530
#           Returns and Exchanges       0.38      0.59      0.46       140
#             Sales and Pre-Sales       0.30      0.55      0.39        85
# Service Outages and Maintenance       0.51      0.79      0.62       110
#               Technical Support       0.61      0.47      0.53       815
#
#                        accuracy                           0.52      2826
#                       macro avg       0.47      0.58      0.51      2826
#                    weighted avg       0.54      0.52      0.52      2826

# %%
x_test_tfidf = vectorizer.transform(x_test)
y_test_pred = svm.predict(x_test_tfidf)

test_accuracy = accuracy_score(y_test, y_test_pred)
test_f1 = f1_score(y_test, y_test_pred, average='macro')

print(f"FINAL TEST ACCURACY: {test_accuracy:.4f}")
print(f"FINAL TEST MACRO F1: {test_f1:.4f}")

print("\n--- Final Test Classification Report ---")
print(classification_report(y_test, y_test_pred))
# Out:
# FINAL TEST ACCURACY: 0.5239
# FINAL TEST MACRO F1: 0.5264
#
# --- Final Test Classification Report ---
#                                  precision    recall  f1-score   support
#
#            Billing and Payments       0.76      0.83      0.80       290
#                Customer Service       0.46      0.38      0.42       427
#                 General Inquiry       0.33      0.78      0.46        40
#                 Human Resources       0.43      0.80      0.56        55
#                      IT Support       0.42      0.46      0.44       334
#                 Product Support       0.53      0.40      0.45       531
#           Returns and Exchanges       0.38      0.59      0.47       140
#             Sales and Pre-Sales       0.40      0.71      0.51        84
# Service Outages and Maintenance       0.51      0.75      0.60       111
#               Technical Support       0.61      0.50      0.55       815
#
#                        accuracy                           0.52      2827
#                       macro avg       0.48      0.62      0.53      2827
#                    weighted avg       0.54      0.52      0.52      2827

# %%
joblib.dump(vectorizer,'../models/SVM/vectorizer.pkl')
joblib.dump(svm, '../models/SVM/svm.pkl')
# Out:
# ['../models/SVM/svm.pkl']

# %%
sgd = make_pipeline(StandardScaler(with_mean=False),SGDClassifier(max_iter=1000, loss='log_loss', class_weight='balanced'))
sgd.fit(X_train_tfidf, y_train)
x_val_tfidf = vectorizer.transform(x_val) 
y_pred_sgd = sgd.predict(x_val_tfidf)

sgd_acc = accuracy_score(y_val, y_pred_sgd)
sgd_f1 = f1_score(y_val, y_pred_sgd, average='macro')

print(f"Validation Accuracy: {sgd_acc:.4f}")
print(f"Validation Macro F1: {sgd_f1:.4f}")

print("\nReport")
print(classification_report(y_val, y_pred_sgd))
# Out:
# Validation Accuracy: 0.5541
# Validation Macro F1: 0.5442
#
# Report
#                                  precision    recall  f1-score   support
#
#            Billing and Payments       0.75      0.80      0.78       289
#                Customer Service       0.50      0.47      0.48       427
#                 General Inquiry       0.36      0.49      0.41        41
#                 Human Resources       0.56      0.68      0.61        56
#                      IT Support       0.48      0.51      0.49       333
#                 Product Support       0.50      0.53      0.51       530
#           Returns and Exchanges       0.48      0.61      0.54       140
#             Sales and Pre-Sales       0.43      0.41      0.42        85
# Service Outages and Maintenance       0.63      0.60      0.62       110
#               Technical Support       0.62      0.54      0.58       815
#
#                        accuracy                           0.55      2826
#                       macro avg       0.53      0.56      0.54      2826
#                    weighted avg       0.56      0.55      0.55      2826

# %%
#vectorizer with n-gram range
n_vectorizer = TfidfVectorizer(ngram_range=(1, 2), stop_words='english', max_features=10000)

print("Vectorizing with N-grams")
x_ngram = n_vectorizer.fit_transform(x_train)
x_val_ngram = n_vectorizer.transform(x_val)
# Out:
# Vectorizing with N-grams

# %%
sgd_ng = make_pipeline(StandardScaler(with_mean=False), SGDClassifier(max_iter=1000, class_weight='balanced', random_state=42))
sgd_ng.fit(x_ngram, y_train)

y_pred_ng = sgd_ng.predict(x_val_ngram)

acc = accuracy_score(y_val, y_pred_ng)
print(f"\nAccuracy: {acc:.4f}")
print(classification_report(y_val, y_pred_ng))
# Out:
# Accuracy: 0.6592
#                                  precision    recall  f1-score   support
#
#            Billing and Payments       0.85      0.83      0.84       289
#                Customer Service       0.59      0.63      0.61       427
#                 General Inquiry       0.57      0.59      0.58        41
#                 Human Resources       0.72      0.61      0.66        56
#                      IT Support       0.58      0.57      0.57       333
#                 Product Support       0.64      0.65      0.64       530
#           Returns and Exchanges       0.68      0.59      0.63       140
#             Sales and Pre-Sales       0.65      0.59      0.62        85
# Service Outages and Maintenance       0.68      0.68      0.68       110
#               Technical Support       0.68      0.68      0.68       815
#
#                        accuracy                           0.66      2826
#                       macro avg       0.66      0.64      0.65      2826
#                    weighted avg       0.66      0.66      0.66      2826

# %%
joblib.dump(n_vectorizer, '../models/svm/vectorizer.pkl')
joblib.dump(sgd_ng, '../models/svm/svm.pkl')
# Out:
# ['../models/svm/svm.pkl']
